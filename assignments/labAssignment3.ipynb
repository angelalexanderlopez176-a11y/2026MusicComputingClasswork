# %% [markdown]
# <a href="https://colab.research.google.com/github/angelalexanderlopez176-a11y/2026MusicComputingClasswork/blob/main/assignments/labAssignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pylab as plt
import librosa.display
import IPython.display
import librosa

#import audio files
# !git clone https://github.com/jcdevaney/musicComputing2026.git
# Out:
# fatal: destination path 'musicComputing2026' already exists and is not an empty directory.

# %%
def plotAudio2(sig,sampleRate,title):
  time=np.arange(0,sig.shape[0])/sampleRate
  excursion=max(abs(sig))
  sigNew = sig / excursion
  xlabel = 'Time (seconds)'
  ylabel = 'Amplitude'
  plt.plot(time,sigNew)
  plt.xlabel(xlabel)
  plt.ylabel(ylabel)
  plt.title(title)
  plt.show()
    # add in the code from Assignment 2

# %%
def plotAudioFreqDomain(sig,sr,title,winSize,specType):
  spec = librosa.amplitude_to_db(np.abs(librosa.stft(sig,n_fft=winSize)),ref=np.max)
  librosa.display.specshow(spec, y_axis=specType)
  plt.colorbar(format='%+2.0f dB')
  plt.title('Log-frequency power spectrogram')
  plt.show()




    # create a normalized spectrogram
    # this includes several function calls
    # first create a basic specgrogram with librosa.stft() with the default window size (2048)
    # then make all of values in the spectrogram positive with np.abs()
    # then scale the spectogram to be in decibels, so it better reflects how we hear librosa.amplitude_to_db()

    # display the normalized spectrogram with a log frequency scale

# %%
def plotAudioFunc(sig,sr,title,winSize,specType):
  plotAudio2(sig,sr,title)
  plotAudioFreqDomain(sig,sr,title,winSize,specType)

    #call plotAudio2

    #call plotAudioFreqDomain

# %%
sig , sr = librosa.load('musicComputing2026/audioFiles/avm.wav')
IPython.display.Audio(data=sig, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
title = 'Ave Maria'
winSize = 2048
specType = 'linear'
plotAudioFunc(sig,sr,title,winSize,specType)
#call plotAudioFunc

# %%
title = 'Ave Maria'
winSize = 2048
specType = 'log'
plotAudioFunc(sig,sr,title,winSize,specType)
#call plotAudioFunc

# %%
title = 'Ave Maria'
winSize = 256
specType = 'linear'
plotAudioFunc(sig,sr,title,winSize,specType)
#call plotAudioFunc

# %%
title = 'Ave Maria'
winSize = 256
specType = 'log'
plotAudioFunc(sig,sr,title,winSize,specType)
# call plotAudioFunc
