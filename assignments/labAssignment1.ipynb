# %% [markdown]
# <a href="https://colab.research.google.com/github/angelalexanderlopez176-a11y/2026MusicComputingClasswork/blob/main/assignments/labAssignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1) Start by importing the necessary libraries in the first cell of the notebook
# numpy

# matplotlib

# librosa

#import audio files


import numpy as np
import matplotlib.pyplot as plt
import librosa
import librosa.display

# !git clone https://github.com/jcdevaney/musicComputing2026.git
# Out:
# Cloning into 'musicComputing2026'...
# remote: Enumerating objects: 74, done.
# remote: Counting objects: 100% (74/74), done.
# remote: Compressing objects: 100% (69/69), done.
# remote: Total 74 (delta 31), reused 7 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (74/74), 10.95 MiB | 17.52 MiB/s, done.
# Resolving deltas: 100% (31/31), done.

# %%
# 2) Create a function that inputs the name of an audio file and a sampling rate

def plotAudio(file,samplingRate):

  sig, sr = librosa.load(file, sr=samplingRate, mono=True)


  time = np.arange(0, sig.shape[0]) / sr


  excursion = max(abs(sig))
  sigNew = sig / excursion
  print("Max amplitude before normalization:", excursion)


  xlabel = "Time (seconds)"
  ylabel = "Amplitude"


  plt.figure()
  plt.plot(time, sigNew)
  plt.xlabel(xlabel)
  plt.ylabel(ylabel)
  plt.title("Normalized Waveform")
  plt.axis('tight')
  plt.show()

  # In the function you should use librosa.load() to open the specified filename
  # with the specified sampling rate


  # Use variables for the x- and y-labels


  # The function should plot the time-domain (waveform) representation of the
  # audio signal with time in seconds on the x-axis and amplitude on the y-axis


  # Plot the signal

# %%
# 3) Run the function twice (in different cells)
# First use ‘avm.wav’ as the filename with a sampling rate of 44100

file = '/content/musicComputing2026/audioFiles/avm.wav'
samplingRate=44100
plotAudio(file,samplingRate)

sig, sr = librosa.load(file)
# Out:
# Max amplitude before normalization: 0.354187

# %%
file = '/content/musicComputing2026/audioFiles/avm.wav'
samplingRate = 441
plotAudio(file, samplingRate)
# Out:
# Max amplitude before normalization: 0.0025246898

# %%
# Second use ‘avm.wav’ as the filename with a sampling rate of 441
